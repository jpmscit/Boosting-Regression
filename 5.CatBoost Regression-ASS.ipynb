# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes' ]]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from catboost) (3.11.1)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from catboost) (2.5.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from catboost) (1.18.1)
# Collecting plotly (from catboost)
#   Downloading plotly-7.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: six in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\jpmsc\.conda\envs\aiml\Lib\site-packages (from plotly->catboost) (2.25.0)
# Downloading catboost-1.2.10-cp312-cp312-win_amd64.whl (100.2 MB)
#    ---------------------------------------- 0.0/100.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/100.2 MB ? eta -:--:--
#    ---------------------------------------- 1.0/100.2 MB 4.6 MB/s eta 0:00:22
#    -- ------------------------------------- 5.2/100.2 MB 13.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 14.9/100.2 MB 24.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 28.0/100.2 MB 35.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 40.1/100.2 MB 40.5 MB/s eta 0:00:02
#    --------------------- ------------------ 53.7/100.2 MB 44.4 MB/s eta 0:00:02
#    ------------------------- -------------- 63.7/100.2 MB 47.2 MB/s eta 0:00:01
#    -------------------------------- ------- 81.3/100.2 MB 49.4 MB/s eta 0:00:01
#    -------------------------------------- - 96.7/100.2 MB 52.3 MB/s eta 0:00:01
#    --------------------------------------  100.1/100.2 MB 52.0 MB/s eta 0:00:01
#    ---------------------------------------- 100.2/100.2 MB 48.1 MB/s  0:00:02
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading plotly-7.1.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 9.7/9.7 MB 66.9 MB/s  0:00:00
# Installing collected packages: plotly, graphviz, catboost
#
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    ---------------------------------------- 3/3 [catboost]
#
# Successfully installed catboost-1.2.10 graphviz-0.21 plotly-7.1.0

# %%
from catboost import CatBoostRegressor

# %%
regressor = CatBoostRegressor(
    iterations=200,       # number of trees
    learning_rate=0.05,   # shrinkage factor
    depth=6,              # depth of each tree
    verbose=0,            # suppress training output
    random_state=42 )

# %%
regressor.fit(x_train,y_train)
# Out:
# CatBoostRegressor(depth=6, iterations=200, learning_rate=0.05, loss_function='RMSE', random_state=42, verbose=0)

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.890704290308483
